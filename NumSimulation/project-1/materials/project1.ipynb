# %% [markdown]
# # Project1
#
# 1. Initialize the variables: $x$, $v$, B-field, E-field, etc.
#
#
# 2. Calculate the vectors $\vec{t}$ and $\vec{s}$ from Eq. (7) and (9).
#     \begin{align}
#     \vec{t} & = -\hat{b}\cdot\tan\left(\frac{\theta}{2}\right) = \frac{q\vec{B}}{m}\cdot\frac{\Delta t}{2} \\
#     \vec{s} & = \frac{2\vec{t}}{1+|\vec{t}|^2}
#     \end{align}
#
#
# 3. Calculate $v^-$ from the previous $v$ using Eq. (3).
#     \begin{equation}
#     v^- = v_{t-\frac{\Delta t}{2}}+\frac{q\vec{E}}{m}\cdot\frac{\Delta t}{2}
#     \end{equation}
#
#
# 4. Calculate $v'$ and $v^+$ using Eq. (6) and (8).
#     \begin{align}
#     v' & = v^- + v^- \times \vec{t} \\
#     v^+ & = v^- + v' \times \vec{s}
#     \end{align}
#
#
# 5. Calculate the next $v$ from $v^+$ using Eq. (4).
#     $$ v_{t+\frac{\Delta t}{2}} = v^+ + \frac{q\vec{E}}{m}\cdot\frac{\Delta t}{2} $$
#
#
# 6. Integrate the velocities to obtain the positions of the particle.
#     $$ x_{k+1} = x_k + v_k\Delta t $$
#
#
# 7. Repeat step 3 to step 6 for sufficient iterations
#
#
# 8. Plot the positions of the particle and observe its tracjectory.

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from project1 import boris

# initialization
dt = 0.5e-3
qm = 100
n_iter = 1000
initial_v = np.array([2., 3., 4.])
initial_x = np.array([10., 12., 1.])
b_field = np.array([5., 7., 8.])
e_field = np.array([1., 2., 1.])
x_mem = np.zeros((n_iter, 3))

# calculate s and t
t_vec = qm * b_field * 0.5 * dt # eq. 7
s_vec = 2. * t_vec / (1. + t_vec * t_vec) # eq. 9

# boris' algorithm
v = initial_v.copy()
x = initial_x.copy()
for idx in range(n_iter):
    # --- IMPLEMENT BORIS' ALGORITHM (Step 3 to 6) HERE ---
    
    
    
    
    
    
    # -----------------------------------------------------
    # v, x = boris(v, x, qm, e_field, dt, t_vec, s_vec)
    x_mem[idx, :] = x # store the results into the arrays

# plot
fig, ax = plt.subplots(subplot_kw={'projection': '3d'}, figsize=(8,6))
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.plot(x_mem[:, 0], x_mem[:, 1], x_mem[:, 2])
plt.show()
